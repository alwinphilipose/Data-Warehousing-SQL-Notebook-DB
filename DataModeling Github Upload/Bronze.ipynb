# %%
last_load_date= '1900-01-01'

# %%
spark.sql(f"""Select * from datamodelingcatalog.default.source_data
where order_date > '{last_load_date}'""").createOrReplaceTempView("bronze_source")

# %%
# %sql
Create or replace table datamodelingcatalog.bronze.bronze_table AS 
SELECT * FROM bronze_source

# %%
spark.sql("""
 Select *,
  upper(customer_name) as customer_name_upper,
  date(current_timestamp()) as processDate FROM datamodelingcatalog.bronze.bronze_table""").createOrReplaceTempView("silver_source")

# %%
if spark.catalog.tableExists('datamodelingcatalog.silver.silver_table'):
    print("hehe")
else:
    spark.sql("""CREATE Table IF NOT EXISTS datamodelingcatalog.silver.silver_table 
              AS
              SELECT * FROM silver_source""")
